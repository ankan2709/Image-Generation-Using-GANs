# %%
import skimage.io
import numpy as np
import os
import matplotlib.pyplot as plt
import astropy
from PIL import Image

# %%
skimage.io.find_available_plugins()
# Out:
# {'imageio': ['imread', 'imsave', 'imread_collection'],
#  'simpleitk': ['imread', 'imsave', 'imread_collection'],
#  'matplotlib': ['imshow', 'imread', 'imshow_collection', 'imread_collection'],
#  'fits': ['imread', 'imread_collection'],
#  'gtk': ['imshow'],
#  'pil': ['imread', 'imsave', 'imread_collection'],
#  'gdal': ['imread', 'imread_collection'],
#  'imread': ['imread', 'imsave', 'imread_collection'],
#  'qt': ['imshow', 'imsave', 'imread', 'imread_collection'],
#  'tifffile': ['imread', 'imsave', 'imread_collection']}

# %%
imlibs = skimage.io.find_available_plugins()

# %%
os.listdir('output/train')[0]
# Out:
# 'combined_hmi_aia4380.npy'

# %%
np.load('output/train/combined_hmi_aia4380.npy', )
# Out:
# array([[0.       , 0.       , 0.       , ..., 3.4978027, 4.1206055,
#         3.5424805],
#        [0.       , 0.       , 0.       , ..., 4.293457 , 2.2434082,
#         3.1904297],
#        [0.       , 0.       , 0.       , ..., 4.1030273, 4.296875 ,
#         3.8051758],
#        ...,
#        [0.       , 0.       , 0.       , ..., 2.578125 , 3.0688477,
#         2.3935547],
#        [0.       , 0.       , 0.       , ..., 2.3173828, 3.003418 ,
#         2.1850586],
#        [0.       , 0.       , 0.       , ..., 1.8720703, 1.9880371,
#         1.567627 ]], dtype=float32)

# %%
plt.imshow(np.uint32(np.load('output/train/combined_hmi_aia4380.npy')))

# %%
skimage.io.imshow(np.uint32(np.load('output/train/combined_hmi_aia4380.npy')))
skimage.io.show()

# %%
skimage.io.imsave('file1.png', np.uint8(np.load('output/train/combined_hmi_aia4380.npy')))

# %%
data = np.uint8(np.load('output/train/combined_hmi_aia4380.npy'))

# %%
img = Image.fromarray(data)

# %%
img.save('test.png')
