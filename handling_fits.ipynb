# %%
import sunpy
import sunpy.map
import matplotlib.colors as colors
from astropy import *
import astropy.units as u
import pathlib
import json, urllib, numpy as np, matplotlib.pylab as plt, matplotlib.ticker as mtick, requests
import sunpy.map
import drms
from astropy.io import fits
from astropy.coordinates import SkyCoord
import astropy.units as u
from sunpy.cm import color_tables as ct
import sunpy.coordinates
from datetime import datetime as dt_obj
import matplotlib.dates as mdates
import matplotlib.colors as mcol
import matplotlib.patches as ptc
from matplotlib.dates import *
import math

import drms
c = drms.Client()
# Out:
# WARNING: SunpyDeprecationWarning: The functionality of the sunpy.cm module is now in sunpy.visualization.colormaps as of SunPy 1.1. The ability to import sunpy.cm as a module will be removed in a future version of SunPy. [sunpy.cm]

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from astropy.io import fits

# %%
print(len(os.listdir('AIA0304/')))
print(sorted(os.listdir('AIA0304/'))[0])
# Out:
# 730
# aia_lev1_304a_2012_01_01t00_00_08_14z_image_lev1.fits

# %%
aia30401 = fits.open('AIA0304/aia_lev1_304a_2012_01_01t00_00_08_14z_image_lev1.fits')

# %%
aia30401
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f1271798dd8>, <astropy.io.fits.hdu.compressed.CompImageHDU object at 0x7f12716de9b0>]

# %%
aia30401.info()
# Out:
# Filename: AIA0304/aia_lev1_304a_2012_01_01t00_00_08_14z_image_lev1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1                1 CompImageHDU    187   (4096, 4096)   int16

# %%
aia30401[1]

# %%
# aia30401[1].header

# %%
image_data = aia30401[1].data

# %%
type(image_data)
# Out:
# numpy.ndarray

# %%
image_data.shape
# Out:
# (4096, 4096)

# %%
print(f'Min: {np.min(image_data)}')
print(f'Min: {np.max(image_data)}')
print(f'Min: {np.mean(image_data)}')
print(f'Min: {np.std(image_data)}')
# Out:
# Min: -9
# Min: 5832
# Min: 30.659969806671143
# Min: 44.46265459899398

# %%
import sunpy
plt.imshow(image_data, cmap=plt.get_cmap('sdoaia304'))
plt.colorbar()

# %%
# histogram = plt.hist(image_data.flat, bins=500)

# %%
from matplotlib.colors import LogNorm

plt.imshow(image_data, cmap=plt.get_cmap('sdoaia304'), norm=LogNorm())

# %%
aia = fits.open('aia.fits')

# %%
aia_data = aia[0].data

# %%
aia_data.shape
# Out:
# (4096, 4096)

# %%
import sunpy
plt.imshow(aia_data)
plt.colorbar()
